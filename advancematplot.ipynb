# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('E:/courses/Data science/Data science journey/matplotlibe/advancematplot/iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris.sample(5)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 16  17            5.4           3.9            1.3           0.4
# 82  83            5.8           2.7            3.9           1.2
# 6    7            4.6           3.4            1.4           0.3
# 92  93            5.8           2.6            4.0           1.2
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 16      Iris-setosa
# 82  Iris-versicolor
# 6       Iris-setosa
# 92  Iris-versicolor
# 88  Iris-versicolor

# %%
iris['Species']= iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(5)
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_1876\3804414668.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species']= iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 63    64            6.1           2.9            4.7           1.4        1
# 124  125            6.7           3.3            5.7           2.1        2
# 8      9            4.4           2.9            1.4           0.2        0
# 118  119            7.7           2.6            6.9           2.3        2
# 107  108            7.3           2.9            6.3           1.8        2

# %% [markdown]
# %C is used for showing different colors
# %cmap is for rythms of colors
# %alpha is for volume of the colors

# %%
plt.figure(figsize=(10,7))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='plasma',alpha=0.9)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %% [markdown]
# Annotations

# %%
batters = pd.read_csv('E:/courses/Data science/Data science journey/matplotlibe/drive-download-20250107T170533Z-001 (3)/batter.csv')

# %%
plt.figure(figsize=(18,10))
sample_df = batters.head(15).sample(15)
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %% [markdown]
# Horizental and Vertical lines

# %%
plt.figure(figsize=(18,10))
sample_df = batters.head(15).sample(15)
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])

plt.axhline(130, color='red')
plt.axvline(35, color='red')

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %% [markdown]
# Subplotes means more than one plot in a graph

# %%
fig ,ax = plt.subplots(nrows=2,ncols=1,sharex=True)
ax[0].scatter(batters['avg'],batters['strike_rate'],color='red')
ax[0].set_title('Avg Vs Strike_rate')
ax[0].set_ylabel('Strike_Rate')

ax[1].scatter(batters['avg'],batters['runs'],color='green')
ax[1].set_title('Avg Vs Runs')
ax[1].set_ylabel('Runs')
ax[1].set_xlabel('Avg')
# Out:
# Text(0.5, 0, 'Avg')

# %% [markdown]
# We can make four or more graphs at a time

# %%
fig ,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,10))
ax[0,0].scatter(batters['avg'],batters['strike_rate'],color='red')
ax[0,0].set_title('Avg vs Strike')
ax[0,1].scatter(batters['avg'],batters['runs'],color='green',marker='+')
ax[0,1].set_title('Avg vs Runs')
ax[1,0].hist(batters['avg'],color='blue')
ax[1,0].set_title('Avg')
ax[1,1].hist(batters['runs'])
ax[1,1].set_title('Runs')
# Out:
# Text(0.5, 1.0, 'Runs')

# %% [markdown]
# 3D Plotes

# %%
fig = plt.figure()
ax= plt.subplot(projection='3d')
ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'])
ax.set_title('3D Plot')
ax.set_xlabel('Runs')
ax.set_ylabel('Avg')
ax.set_zlabel('SR')
# Out:
# Text(0.5, 0, 'SR')

# %% [markdown]
# 3D Line Ploting

# %%
x = [0,23,12,8]
y = [0,24,4,12]
z = [5,0,10,15]

fig = plt.figure()
ax = plt.subplot(projection='3d')
ax.scatter3D(x,y,z,s=[100,100,100,100])
ax.plot3D(x,y,z,color='red')

# %% [markdown]
# 3D Surface Plot

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

xx,yy = np.meshgrid(x,y)
z = xx**2 + yy**2

fig = plt.figure(figsize=(12,8))
ax = plt.subplot(projection = '3d')
p = ax.plot_surface(xx,yy,z,cmap = 'viridis')
fig.colorbar(p)

# %% [markdown]
# Contour Plot

# %% [markdown]
# when you want to convert 3D plot into 2D so that you can understand more

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.subplot()
p = ax.contour(xx,yy,z,cmap = 'viridis')
fig.colorbar(p)

# %% [markdown]
# Fill contour plot by calling a function contourf

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.subplot()
p = ax.contourf(xx,yy,z,cmap = 'viridis')
fig.colorbar(p)
fig.show()
# Out:
# C:\Users\PMYLS\AppData\Local\Temp\ipykernel_1876\1191208246.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# HeatMap

# %%
delivery = pd.read_csv('E:/courses/Data science/Data science journey/matplotlibe/advancematplot/IPL_Ball_by_Ball_2008_2022.csv')
delivery.head(3)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals

# %% [markdown]
# Here in temp_df we first take ballnumber which is 1,2,3,4,5,6 in a over

# %% [markdown]
# then we take the batsman runs which should be equal to 6

# %%
temp_df = delivery[(delivery['ballnumber'].isin([1,2,3,4,5,6])) & (delivery['batsman_run']==6)]

# %% [markdown]
# Now for displaying in a table we call a function name as pivot_table

# %% [markdown]
# we pass "overs" as index "ballnumber" as coloums and we want the values of "batsman_run

# %% [markdown]
# we apply the aggregate function to count all the number of sixes per ball

# %%
grid = temp_df.pivot_table(index='overs',columns='ballnumber',values='batsman_run',aggfunc='count')

# %% [markdown]
# Now we have to make a heatmap chart of the varible name as "grid"

# %%
plt.figure(figsize=(10,8))
plt.imshow(grid)
plt.yticks(delivery['overs'].unique(),list(range(1,21)))
plt.xticks(np.arange(0,6),list(range(1,7)))
plt.colorbar()

# %% [markdown]
# Pandas Plote

# %%
#Ploting on series
s = pd.Series([1,2,3,4,5,7,9])
s.plot(kind="bar")
# Out:
# <Axes: >

# %%
temp = pd.read_csv('E:/courses/Data science/Data science journey/matplotlibe/advancematplot/batsman_season_record.csv')
temp
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
temp['2016'].plot(kind='bar')
# Out:
# <Axes: >

# %%
temp.plot(kind='bar')
# Out:
# <Axes: >

# %%
temp.plot(kind='bar',stacked=True,x='batsman')
# Out:
# <Axes: xlabel='batsman'>

# %% [markdown]
# Pie chart

# %%
df = pd.DataFrame(
    {
    'batsman':['Taimoor','Abubakar','Najaf','Sufyan','Hussain'],
    'match1' :[23,34,45,56,23],
    'match2':[0,23,67,84,23],
    'match3':[90,45,32,0,87]
    }
)
df.head()
# Out:
#     batsman  match1  match2  match3
# 0   Taimoor      23       0      90
# 1  Abubakar      34      23      45
# 2     Najaf      45      67      32
# 3    Sufyan      56      84       0
# 4   Hussain      23      23      87

# %%
df['match1'].plot(kind='pie',labels=df['batsman'].values,autopct='%0.1f%%')
# Out:
# <Axes: ylabel='match1'>

# %% [markdown]
# Multiple Pie charts

# %%
df[['match1','match2','match3']].plot(kind='pie',subplots=True,figsize=(15,6),labels=df['batsman'].values)
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)
